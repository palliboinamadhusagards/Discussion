# %%
class Elder:
    
    true_elderlist = []
    
    elder_list = []
    
    @classmethod
    def addElder(cls, elder):
        cls.elder_list.append(elder)
        
    @classmethod
    def get_elder(cls, name):
        for elder in cls.elder_list:
            if elder.name == name:
                return elder
    
    @classmethod
    def truestatuslist(cls,obj):
        if obj.status:
            if obj.name not in cls.true_elderlist: 
                cls.true_elderlist.append(obj.name)
        else:
            pass
    
    def __init__(self,name,email, password,current_balance):
        self.name = name
        self.email = email
        self.password = password
        self.status = ""
        self.current_balance = current_balance
        self.amount = 0
        self.approve = False
        self.youngername = ""
        self.review = {}
        self.rating = {}
        
        Elder.addElder(self)
        
    
    def login(self, email, password):
        if self.email == email and self.password == password:
            return "Login Successfully"
        else:
            return "Enter username and password not valid try again"
        
    def elder_dashboard(self):
        if self.status == 1:
            print("You are currently available to take care of.\n 1.Status_change\n2.Pay for younger\n3.Accept request\n4.Younger details\n5.Reviews and Ratings\n6.Log out")
            choice = int(input())
            if choice == 1:
                self.status_change()
            
            elif choice == 2:
                self.pay_younger()
                            
            if choice == 3:
                self.accept_request()
                 
            if choice == 4:
                self.younger_details()
                            
            if choice == 5:
                self.review_ratings()
            
            if choice == 6:
                self.logout()
        
        else:
            print("You are currently unavailable to take care of.\n 1.Change status \n2.Log out")
            choice = int(input())
            if choice == 1:
                self.status_change()
          
            elif choice == 2:
                self.logout()
            
    def status_change(self):
        choice = int(input("Enter your status:\n 1. Availabe \n 2. Unavilable \nEnter your option"))
        if choice == 1:
            self.status = True
            Elder.truestatuslist(self)
        
        elif choice == 2:
            self.status = False
        
        print("Status changed")

        self.elder_dashboard()
        
    def get_elderstatus(self):
         return self.status
        
    def get_approvestatus(self):
        return self.approve
    
          
    def pay_younger(self):
        amount = int(input("Enter fee amount for younger:"))
        self.amount = amount
        balance = self.current_balance - self.amount
        
        younger = Younger.get_younger(self.youngername)
        print("Elder {} paid fee {} for the younger {} who take care.The remaining balance is {}.".format(self.name,self.amount,self.youngername,balance))
        younger.current_balance += amount
        print("Younger {} available balance is {}".format(self.youngername, younger.current_balance))
        
    def get_youngerfee(self):
        return self.amount
          
    def accept_request(self, name):
        approve = ""
        print(f"Younger person {name} is requesting for approval")
        choice = int(input("Enter your status:\n 1. Approve \n 2. Not Approve \n 3. Enter your option"))
        if choice == 1:
            self.approve = True
            self.youngername = name
            print("Approve")
        elif choice == 2:
            self.approve = False
            print("Not approve")
            
            self.elder_dashboard()
                     
    def younger_details(self):
        younger = Younger.get_younger(self.youngername)
        print("Younger details who is taking care of elder {} :\n".format(self.name))
        print("Younger name: {}".format(younger.name))
    
    def review_rating(self):
        print("Kindly provide your review and rating for the elder whom you taken care of...")
        review_id = input("Enter younger ID:")
        younger = Younger.get_elder(review_id)
        
        if younger:
            review_user = input("Provide your review:")
            rating_user = int(input("Provide rating for user on a scale of 1 to 5:"))
            
            if self.review.get(review_id):  #will get value if present else none
                self.review.get(review_id).append(review_user)
                self.rating.get(review_id).append(rating_user)
            else:
                self.review.setdefault(review_id, [review_user])
                self.rating.setdefault(review_id, [rating_user])
            
            print(self.review[review_id], self.rating[review_id])
            
        else:
            print("Invalid review id")
           
    def logout(self):
        return False

# %%
class Younger(Elder):
    younger_list = []

    @classmethod
    def add_younger(cls, younger):
        cls.younger_list.append(younger)
    
    @classmethod
    def get_younger(cls, name):
        for younger in cls.younger_list:
            if younger.name == name:
                return younger
          
    def __init__(self,name,email, password,current_balance):
        self.name = name
        self.email = email
        self.password = password
        self.current_balance = current_balance
        self.youngercount = []
        self.review = {}
        self.rating = {}
        
        Younger.add_younger(self)
        
    def login(self, email, password):
        if self.email == email and self.password == password:
            return "Login Successfully"
        else:
            return "Enter username and password not valid try again"
        
    def younger_dashboard(self):
        eldercount = len(self.youngercount)
        print("Currently you are taking care of {eldercount} Elders, You can request for (4-{eldercount}) elders.\n 1.Request Elder\n2.Reviews and Ratings\n3.Log out".format(eldercount = eldercount))
        choice = int(input())
        
        if choice == 1:
            self.request_elder()
            
        if choice == 2:
            self.review_rating()
                            
        if choice == 6:
            self.logout()
                
    def request_elder(self):
        eldercount = len(self.youngercount)
               
        if eldercount <= 4:
            request = input("Enter Elder name whom you want to take care:")
           
            if request in Elder.true_elderlist:
                print("Your request is been accepted and under process...")
                elder = Elder.get_elder(request)
                elder.accept_request(self.name)
                if elder.get_approvestatus() == True:
                    self.youngercount.append(request)
                else:
                    elder.accept_request()
            else:
                print("Invalid option, please select from above choices")
        else:
            print("You are already taking care of 4 elders. So, you are not eligile to send another request")
        
        self.younger_dashboard()
            
    def review_rating(self):
        print("Kindly provide your review and rating for the elder whom you taken care of...")
        review_id = input("Enter Elder ID:")
        elder = Elder.get_elder(review_id)
        
        if elder:
            review_user = input("Provide your review:")
            rating_user = int(input("Provide rating for user on a scale of 1 to 5:"))
            
            if self.review.get(review_id):  #will get value if present else none
                self.review.get(review_id).append(review_user)
                self.rating.get(review_id).append(rating_user)
            else:
                self.review.setdefault(review_id, [review_user])
                self.rating.setdefault(review_id, [rating_user])
            
            avg_rating = sum(self.rating[review_id]) / len(self.rating[review_id])
            print(self.review[review_id], self.rating[review_id])
            print("Average rating for elder '{}' : {}".format(elder.name, avg_rating))
            
        else:
            print("Invalid review id")
        
    def younger_fee(self):
        pass
        
    def get_elderlist(self):
        eld_list = self.youngercount
        return eld_list
    
    def get_youngerdetails(self):
        return self.name

# %%
ed1 = Elder("abc","abc@xyz.com", 123,10000)
ed2 = Elder("pqr","pqr@xyz.com", 132,25000)
ed3 = Elder("klm","klm@xyz.com", 123,10000)
ed4 = Elder("uvw","uvw@xyz.com", 132,25000)
ed5 = Elder("efg","efg@xyz.com", 123,10000)
ed6 = Elder("hij","hij@xyz.com", 132,25000)

# %%
yng1 = Younger("stu","stu@xyz.com", 321,0)
yng2 = Younger("klm","klm@xyz.com", 232,0)

# %%
ed1.elder_dashboard()
# Out:
# You are currently unavailable to take care of.
#  1.Change status
# 2.Log out
# 1
# Enter your status:
#  1. Availabe
#  2. Unavilable
# Enter your option1
# Status changed
# You are currently available to take care of.
#  1.Status_change
# 2.Pay for younger
# 3.Accept request
# 4.Younger details
# 5.Reviews and Ratings
# 6.Log out
# 6

# %%
yng1.younger_dashboard()
# Out:
# Currently you are taking care of 0 Elders, You can request for (4-0) elders.
#  1.Request Elder
# 2.Reviews and Ratings
# 3.Log out
# 1
# Enter Elder name whom you want to take care:abc
# Your request is been accepted and under process...
# Younger person stu is requesting for approval
# Enter your status:
#  1. Approve
#  2. Not Approve
#  3. Enter your option1
# Approve
# Currently you are taking care of 1 Elders, You can request for (4-1) elders.
#  1.Request Elder
# 2.Reviews and Ratings
# 3.Log out
# 3

# %%
ed1.elder_dashboard()
# Out:
# You are currently available to take care of.
#  1.Status_change
# 2.Pay for younger
# 3.Accept request
# 4.Younger details
# 5.Reviews and Ratings
# 6.Log out
# 2
# Enter fee amount for younger:2500
# Elder abc paid fee 2500 for the younger stu who take care.The remaining balance is 7500.
# Younger stu available balance is 2500

# %%
yng1.younger_dashboard()
# Out:
# Currently you are taking care of 1 Elders, You can request for (4-1) elders.
#  1.Request Elder
# 2.Reviews and Ratings
# 3.Log out
# 2
# Kindly provide your review and rating for the elder whom you taken care of...
# Enter Elder ID:abc
# Provide your review:good
# Provide rating for user on a scale of 1 to 5:3
# ['good'] [3]
# Average rating for elder 'abc' : 3.0

# %%
ed1.elder_dashboard()
# Out:
# You are currently available to take care of.
#  1.Status_change
# 2.Pay for younger
# 3.Accept request
# 4.Younger details
# 5.Reviews and Ratings
# 6.Log out
# 4
# Younger details who is taking care of elder abc :
#
# Younger name: stu

# %%
class index(Elder,Younger):
